# %% [markdown]
# **Kelompok 13:**
# 1. Dini Soraya (2217051107)
# 2. Naura Salsabila (2217051079)
# 3. Pradya Hening Pertiwi (2217051005)

# %% [markdown]
# # No 1

# %% [markdown]
# ## Dataset .txt

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/dinisoraya/uts-pdt/main/CellPhone_train.txt')
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
column_sum = df.sum()
column_mean = df.mean()
column_median = df.median()

stats_df = pd.DataFrame({
    'Sum': column_sum,
    'Mean': column_mean,
    'Median': column_median
})

stats_df
# Out:
#                      Sum        Mean  Median
# battery_power  2477037.0  1238.51850  1226.0
# blue               990.0     0.49500     0.0
# clock_speed       3044.5     1.52225     1.5
# dual_sim          1019.0     0.50950     1.0
# fc                8619.0     4.30950     3.0
# four_g            1043.0     0.52150     1.0
# int_memory       64093.0    32.04650    32.0
# m_dep             1003.5     0.50175     0.5
# mobile_wt       280498.0   140.24900   141.0
# n_cores           9041.0     4.52050     4.0
# pc               19833.0     9.91650    10.0
# px_height      1290216.0   645.10800   564.0
# px_width       2503031.0  1251.51550  1247.0
# ram            4248426.0  2124.21300  2146.5
# sc_h             24613.0    12.30650    12.0
# sc_w             11534.0     5.76700     5.0
# talk_time        22022.0    11.01100    11.0
# three_g           1523.0     0.76150     1.0
# touch_screen      1006.0     0.50300     1.0
# wifi              1014.0     0.50700     1.0
# ...

# %% [markdown]
# ## Dataset .csv

# %%
df2 = pd.read_csv('https://raw.githubusercontent.com/dinisoraya/uts-pdt/main/Coffee_Qlty.csv')
df2.head()
# Out:
#    REC_ID  Species Continent.of.Origin Country.of.Origin  Harvest.Year  \
# 0       0  Arabica              Africa          Ethiopia        2014.0
# 1       1  Arabica              Africa          Ethiopia        2014.0
# 2       2  Arabica       North America         Guatemala           NaN
# 3       3  Arabica              Africa          Ethiopia        2014.0
# 4       4  Arabica              Africa          Ethiopia        2014.0
#
#   Expiration  Variety  Color Processing.Method  Aroma  ...  Acidity  Body  \
# 0   04/03/16      NaN  Green      Washed / Wet   8.67  ...     8.75  8.50
# 1   04/03/16    Other  Green      Washed / Wet   8.75  ...     8.58  8.42
# 2   05/31/11  Bourbon    NaN               NaN   8.42  ...     8.42  8.33
# 3   03/25/16      NaN  Green     Natural / Dry   8.17  ...     8.42  8.50
# 4   04/03/16    Other  Green      Washed / Wet   8.25  ...     8.50  8.42
#
#    Balance  Uniformity  Clean.Cup  Sweetness  Moisture  Quakers  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1339 entries, 0 to 1338
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   REC_ID                1339 non-null   int64
#  1   Species               1339 non-null   object
#  2   Continent.of.Origin   1338 non-null   object
#  3   Country.of.Origin     1338 non-null   object
#  4   Harvest.Year          1279 non-null   float64
#  5   Expiration            1339 non-null   object
#  6   Variety               1113 non-null   object
#  7   Color                 1069 non-null   object
#  8   Processing.Method     1169 non-null   object
#  9   Aroma                 1339 non-null   float64
#  10  Flavor                1339 non-null   float64
#  11  Aftertaste            1339 non-null   float64
#  12  Acidity               1339 non-null   float64
#  13  Body                  1339 non-null   float64
# ...

# %%
numerical_columns = df2.select_dtypes(include=['float64', 'int64']).columns

# %%
column_sum = df2[numerical_columns].sum()
column_mean = df2[numerical_columns].mean()
column_median = df2[numerical_columns].median()

stats_df = pd.DataFrame({
    'Sum': column_sum,
    'Mean': column_mean,
    'Median': column_median
})

stats_df
# Out:
#                              Sum         Mean   Median
# REC_ID                 895791.00   669.000000   669.00
# Harvest.Year          2575353.00  2013.567631  2013.00
# Aroma                   10131.82     7.566706     7.58
# Flavor                  10069.85     7.520426     7.58
# Aftertaste               9910.05     7.401083     7.42
# Acidity                 10090.31     7.535706     7.58
# Body                    10065.93     7.517498     7.50
# Balance                 10066.62     7.518013     7.50
# Uniformity              13168.90     9.834877    10.00
# Clean.Cup               13169.21     9.835108    10.00
# Sweetness               13198.11     9.856692    10.00
# Moisture                  118.34     0.088379     0.11
# Quakers                   232.00     0.173264     0.00
# Category.One.Defects      642.00     0.479462     0.00
# Category.Two.Defects     4762.00     3.556385     2.00

# %% [markdown]
# # No 2

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread('koin.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap='gray');

# %%
blur = cv2.GaussianBlur(gray, (11,11), 0)
plt.imshow(blur, cmap='gray')

# %%
canny = cv2.Canny(blur, 30, 150, 3)
plt.imshow(canny, cmap='gray')

# %%
dilated = cv2.dilate(canny, (1,1), iterations = 2)
plt.imshow(dilated, cmap='gray')

# %%
(cnt, heirarchy) = cv2.findContours(dilated.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
cv2.drawContours(rgb, cnt, -1, (0,255,0), 2)
# Out:
# array([[[233, 236, 229],
#         [238, 241, 234],
#         [241, 244, 237],
#         ...,
#         [249, 250, 245],
#         [250, 251, 246],
#         [250, 251, 246]],
#
#        [[233, 236, 229],
#         [238, 241, 234],
#         [241, 244, 237],
#         ...,
#         [250, 251, 246],
#         [250, 251, 246],
#         [251, 252, 247]],
#
#        [[233, 236, 229],
#         [238, 241, 234],
#         [241, 244, 237],
#         ...,
#         [250, 251, 246],
#         [250, 251, 246],
#         [251, 252, 247]],
#
#        ...,
#
#        [[211, 214, 205],
#         [230, 233, 224],
#         [231, 234, 225],
#         ...,
#         [245, 247, 242],
#         [245, 247, 242],
#         [245, 247, 242]],
#
#        [[205, 208, 199],
#         [224, 227, 218],
#         [226, 229, 220],
#         ...,
#         [244, 246, 241],
#         [244, 246, 241],
#         [244, 246, 241]],
#
#        [[199, 202, 193],
#         [218, 221, 212],
#         [221, 224, 215],
# ...

# %%
plt.imshow(rgb)

# %%
print('Jumlah koin pada gambar: ', len(cnt))
plt.show()
# Out:
# Jumlah koin pada gambar:  24
